# %% [markdown]
# Exercise 1A

# %%
a = 3
a + 2
a = a + 2

x = 4
y = 7
z = x + y

a = 7
b = a
a = 9
# answer is 7

# %% [markdown]
# Exercise 1B

# %%
9 / 2 + 2
6 + 4 * 4
4 / 6 + 2
2 - 3 * 2 - 4
(7 - 5) * (7 + 5)
(3 * (4 - 2 * (3) + 4))

2**3
3**2 - 4**2
2**2**3
2**(2**3)

if 3 * (2 + 3**2) == 33:
  print(True)
else:
  print(False)

if 4**2 + 3**3 + 2**4 + 1 == 70:
  print(True)
else:
  print(False)

if 1 / (1/2 + 1/3 + 1/6) == 1:
  print(True)
else:
  print(False)
# Out:
# True

# %% [markdown]
# Exercise 1C

# %%
import math
help(math.sin)

math.sin(0.5*math.pi)
math.sin(90)

if math.floor(2.5) == math.trunc(2.5):
  print(True)
else:
  print(False)

if math.ceil(-3.6) == math.trunc(-3.2):
  print(True)
else:
  print(False)

if round(3.4) == math.ceil(3.4):
  print(True)
else:
  print(False)

if round(-3.4) == math.ceil(-3.4):
  print(True)
else:
  print(False)

print(round(1234.56789,3))
print(round(1234.56789,1))
print(round(1234.56789,0))
print(round(1234.56789)) # not sure how

help(math.log) # (base e) of x

# %% [markdown]
# Exercise 1D

# %%
math.pi
math.sqrt(25)

A = 30
r = math.sqrt(A / math.pi)
print(r)

a = 51
b = math.log(a)
# a contains 51, b contains the log of 51
a = "fiftyone"
b = math.log(a)
# a was changed from an integer to a string
# Out:
# 3.0901936161855166

# %% [markdown]
# Exercise 1F

# %%
WhatISay = 'Hello CodeJudge!'

# %% [markdown]
# Exercise 1G

# %%
b = 12
c = 10
A = 0.25 * math.pi

a = math.sqrt(b**2 + c**2 - 2 * b * c * math.cos(A))
print(a)
# Out:
# 8.619418339727373

# %% [markdown]
# Exercise 1H

# %%
import math

a = 2
b = -5
c = 2

solutions = []
solutions.append((-b + math.sqrt(b**2 - 4 * a * c)) / (2 * a))
solutions.append((-b - math.sqrt(b**2 - 4 * a * c)) / (2 * a))
x1 = min(solutions)
x2 = max(solutions)
print(x1, x2) # not sure why it's wrong
# Out:
# 0.5 2.0
